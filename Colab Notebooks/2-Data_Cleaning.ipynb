# %%
data_science_jobs = [
    {'job_title': 'Data Scientist', 'job_skills': "['Python', 'SQL', 'Machine Learning']", 'job_date': '2023-02-24'},
    {'job_title': 'Machine Learning Engineer', 'job_skills': "['TensorFlow', 'PyTorch', 'Deep Learning']", 'job_date': '2023-03-01'},
    {'job_title': 'Data Analyst', 'job_skills': "['Excel', 'Power BI', 'SQL']", 'job_date': '2023-04-15'},
    {'job_title': 'Business Intelligence Analyst', 'job_skills': "['Tableau', 'SQL', 'Data Visualization']", 'job_date': '2023-05-08'},
    {'job_title': 'AI Researcher', 'job_skills': "['NLP', 'Computer Vision', 'Python']", 'job_date': '2023-06-20'},
    {'job_title': 'Big Data Engineer', 'job_skills': "['Hadoop', 'Spark', 'Scala']", 'job_date': '2023-07-05'},
    {'job_title': 'Data Engineer', 'job_skills': "['ETL Pipelines', 'AWS', 'SQL']", 'job_date': '2023-08-12'},
    {'job_title': 'Data Scientist Intern', 'job_skills': "['Python', 'R', 'Statistical Analysis']", 'job_date': '2023-09-18'},
    {'job_title': 'Research Data Scientist', 'job_skills': "['Matplotlib', 'Pandas', 'Hypothesis Testing']", 'job_date': '2023-10-25'},
    {'job_title': 'Quantitative Analyst', 'job_skills': "['Matlab', 'Statistics', 'Financial Modeling']", 'job_date': '2023-11-30'},
    {'job_title': 'AI Product Manager', 'job_skills': "['Project Management', 'Data Analysis', 'AI Ethics']", 'job_date': '2023-12-10'},
    {'job_title': 'Data Quality Analyst', 'job_skills': "['SQL', 'Data Cleaning', 'Data Validation']", 'job_date': '2024-01-05'},
    {'job_title': 'Analytics Consultant', 'job_skills': "['Data Interpretation', 'Business Intelligence', 'SQL']", 'job_date': '2024-01-20'},
    {'job_title': 'Predictive Modeler', 'job_skills': "['R', 'Python', 'Time Series Analysis']", 'job_date': '2024-02-14'},
    {'job_title': 'Cloud Data Engineer', 'job_skills': "['Azure', 'Docker', 'Kubernetes']", 'job_date': '2024-03-01'},
    {'job_title': 'Data Science Manager', 'job_skills': "['Team Leadership', 'Project Planning', 'Data Strategy']", 'job_date': '2024-03-15'},
    {'job_title': 'Bioinformatics Data Scientist', 'job_skills': "['Python', 'Genomics', 'Data Mining']", 'job_date': '2024-04-05'},
    {'job_title': 'Marketing Data Analyst', 'job_skills': "['Google Analytics', 'SEO', 'SQL']", 'job_date': '2024-05-18'},
    {'job_title': 'Fraud Detection Analyst', 'job_skills': "['Anomaly Detection', 'Machine Learning', 'Python']", 'job_date': '2024-06-22'},
    {'job_title': 'Operations Research Analyst', 'job_skills': "['Optimization', 'Linear Programming', 'Data Analysis']", 'job_date': '2024-07-10'},
]

# %%
from datetime import datetime
datetime.now()
# Out:
# datetime.datetime(2025, 3, 27, 9, 8, 59, 220156)

# %%
test_date = data_science_jobs[0]["job_date"]

# %%
datetime.strptime(test_date, '%Y-%m-%d')
# Out:
# datetime.datetime(2023, 2, 24, 0, 0)

# %%
import ast

for job in data_science_jobs:
  job["job_date"] = datetime.strptime(job["job_date"], '%Y-%m-%d')
  job["job_skills"] = ast.literal_eval(job['job_skills'])

# %%
data_science_jobs
# Out:
# [{'job_title': 'Data Scientist',
#   'job_skills': ['Python', 'SQL', 'Machine Learning'],
#   'job_date': datetime.datetime(2023, 2, 24, 0, 0)},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': ['TensorFlow', 'PyTorch', 'Deep Learning'],
#   'job_date': datetime.datetime(2023, 3, 1, 0, 0)},
#  {'job_title': 'Data Analyst',
#   'job_skills': ['Excel', 'Power BI', 'SQL'],
#   'job_date': datetime.datetime(2023, 4, 15, 0, 0)},
#  {'job_title': 'Business Intelligence Analyst',
#   'job_skills': ['Tableau', 'SQL', 'Data Visualization'],
#   'job_date': datetime.datetime(2023, 5, 8, 0, 0)},
#  {'job_title': 'AI Researcher',
#   'job_skills': ['NLP', 'Computer Vision', 'Python'],
#   'job_date': datetime.datetime(2023, 6, 20, 0, 0)},
#  {'job_title': 'Big Data Engineer',
#   'job_skills': ['Hadoop', 'Spark', 'Scala'],
#   'job_date': datetime.datetime(2023, 7, 5, 0, 0)},
#  {'job_title': 'Data Engineer',
#   'job_skills': ['ETL Pipelines', 'AWS', 'SQL'],
# ...
